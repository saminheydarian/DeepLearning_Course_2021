# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.layers import Input, SimpleRNN, Dense

# %%
train_csv_path = "drive/MyDrive/Deep_learning/HW6/train.csv"
train_df = pd.read_csv(train_csv_path)
train_df.index = train_df["time"]
train_df.drop("time", inplace=True, axis=1)

# %%
train_df
# Out:
#           value
# time
# 0     52.483570
# 1     49.352749
# 2     53.314735
# 3     57.711823
# 4     48.934444
# ...         ...
# 995   62.874840
# 996   73.281693
# 997   67.510696
# 998   61.464104
# 999   67.196739
#
# [1000 rows x 1 columns]

# %%
def show_raw_visualization(data):
    ax = data.plot(title="value")

show_raw_visualization(train_df)

# %%
test_csv_path = "drive/MyDrive/Deep_learning/HW6/test.csv"
test_df = pd.read_csv(test_csv_path)
test_df.index = test_df["time"]
test_df.drop("time", inplace=True, axis=1)

# %%
test_df
# Out:
#            value
# time
# 1000   71.344719
# 1001   68.985519
# 1002   64.675201
# 1003   61.157360
# 1004   67.898438
# ...          ...
# 1456   88.624756
# 1457   86.796989
# 1458   91.373253
# 1459   88.323830
# 1460  122.307716
#
# [461 rows x 1 columns]

# %%
show_raw_visualization(test_df)

# %%
past = 40
future = 1
learning_rate = 0.001
batch_size = 32
epochs = 300
step = 1

# %%
y_start = past + future - 1
x_end = len(train_df) - past - future

x_train = train_df.loc[:x_end]
y_train = train_df.loc[y_start:]

sequence_length = int(past / step)

# %%
dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=sequence_length,
    batch_size=batch_size,
)

# %%
test_start_point = 999

# %%
y_start = test_start_point + past + future
x_end = test_start_point + (len(test_df) - past - future + 1)

x_test = test_df.loc[:x_end]
y_test = test_df.loc[y_start:]

sequence_length = int(past / step)

# %%
dataset_test = keras.preprocessing.timeseries_dataset_from_array(
    x_test,
    y_test,
    sequence_length=sequence_length,
    batch_size=batch_size,
)

# %%
for batch in dataset_train.take(1):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
# Out:
# Input shape: (32, 40, 1)
# Target shape: (32, 1)

# %%
inputs = Input(shape=(None, inputs.shape[2]))
rnn_out_1 = SimpleRNN(64, return_sequences=True)(inputs)
rnn_out_2 = SimpleRNN(64)(rnn_out_1)
outputs = Dense(1)(rnn_out_2)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse", metrics=[tf.keras.metrics.MeanAbsoluteError()])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, 1)]         0
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, None, 64)          4224
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 64)                8256
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 12,545
# Trainable params: 12,545
# Non-trainable params: 0
# _________________________________________________________________

# %%
path_checkpoint = "model_checkpoint.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=5)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_test,
    callbacks=[es_callback, modelckpt_callback],
)
# Out:
# Epoch 1/300
# 29/29 [==============================] - 3s 42ms/step - loss: 1034.4468 - mean_absolute_error: 28.0614 - val_loss: 4971.7866 - val_mean_absolute_error: 68.8267
#
# Epoch 00001: val_loss improved from inf to 4971.78662, saving model to model_checkpoint.h5
# Epoch 2/300
# 29/29 [==============================] - 1s 28ms/step - loss: 753.9280 - mean_absolute_error: 22.7287 - val_loss: 4656.9751 - val_mean_absolute_error: 66.5003
#
# Epoch 00002: val_loss improved from 4971.78662 to 4656.97510, saving model to model_checkpoint.h5
# Epoch 3/300
# 29/29 [==============================] - 1s 29ms/step - loss: 665.5025 - mean_absolute_error: 21.0256 - val_loss: 4423.8218 - val_mean_absolute_error: 64.7236
#
# Epoch 00003: val_loss improved from 4656.97510 to 4423.82178, saving model to model_checkpoint.h5
# Epoch 4/300
# 29/29 [==============================] - 1s 29ms/step - loss: 602.1807 - mean_absolute_error: 19.7819 - val_loss: 4216.2676 - val_mean_absolute_error: 63.0999
#
# Epoch 00004: val_loss improved from 4423.82178 to 4216.26758, saving model to model_checkpoint.h5
# Epoch 5/300
# 29/29 [==============================] - 1s 28ms/step - loss: 547.2750 - mean_absolute_error: 18.6268 - val_loss: 4024.8987 - val_mean_absolute_error: 61.5648
#
# Epoch 00005: val_loss improved from 4216.26758 to 4024.89868, saving model to model_checkpoint.h5
# Epoch 6/300
# 29/29 [==============================] - 1s 28ms/step - loss: 498.1453 - mean_absolute_error: 17.4989 - val_loss: 3846.4019 - val_mean_absolute_error: 60.0977
#
# Epoch 00006: val_loss improved from 4024.89868 to 3846.40186, saving model to model_checkpoint.h5
# Epoch 7/300
# 29/29 [==============================] - 1s 28ms/step - loss: 454.1700 - mean_absolute_error: 16.4145 - val_loss: 3679.0696 - val_mean_absolute_error: 58.6891
#
# Epoch 00007: val_loss improved from 3846.40186 to 3679.06958, saving model to model_checkpoint.h5
# Epoch 8/300
# 29/29 [==============================] - 1s 27ms/step - loss: 413.8863 - mean_absolute_error: 15.3145 - val_loss: 3521.3489 - val_mean_absolute_error: 57.3296
#
# Epoch 00008: val_loss improved from 3679.06958 to 3521.34888, saving model to model_checkpoint.h5
# Epoch 9/300
# 29/29 [==============================] - 1s 28ms/step - loss: 376.7033 - mean_absolute_error: 14.2568 - val_loss: 3372.2705 - val_mean_absolute_error: 56.0144
#
# Epoch 00009: val_loss improved from 3521.34888 to 3372.27051, saving model to model_checkpoint.h5
# Epoch 10/300
# 29/29 [==============================] - 1s 28ms/step - loss: 344.6828 - mean_absolute_error: 13.3070 - val_loss: 3231.7864 - val_mean_absolute_error: 54.7460
#
# Epoch 00010: val_loss improved from 3372.27051 to 3231.78638, saving model to model_checkpoint.h5
# Epoch 11/300
# 29/29 [==============================] - 1s 28ms/step - loss: 315.6102 - mean_absolute_error: 12.4243 - val_loss: 3099.5828 - val_mean_absolute_error: 53.5249
#
# Epoch 00011: val_loss improved from 3231.78638 to 3099.58276, saving model to model_checkpoint.h5
# Epoch 12/300
# 29/29 [==============================] - 1s 28ms/step - loss: 290.4404 - mean_absolute_error: 11.6817 - val_loss: 2975.2522 - val_mean_absolute_error: 52.3506
#
# Epoch 00012: val_loss improved from 3099.58276 to 2975.25220, saving model to model_checkpoint.h5
# Epoch 13/300
# 29/29 [==============================] - 1s 28ms/step - loss: 268.4820 - mean_absolute_error: 11.0458 - val_loss: 2858.5503 - val_mean_absolute_error: 51.2239
#
# Epoch 00013: val_loss improved from 2975.25220 to 2858.55029, saving model to model_checkpoint.h5
# Epoch 14/300
# 29/29 [==============================] - 1s 28ms/step - loss: 249.4083 - mean_absolute_error: 10.4977 - val_loss: 2749.0022 - val_mean_absolute_error: 50.1432
#
# Epoch 00014: val_loss improved from 2858.55029 to 2749.00220, saving model to model_checkpoint.h5
# Epoch 15/300
# 29/29 [==============================] - 1s 29ms/step - loss: 233.8706 - mean_absolute_error: 10.1039 - val_loss: 2645.9937 - val_mean_absolute_error: 49.1053
#
# Epoch 00015: val_loss improved from 2749.00220 to 2645.99365, saving model to model_checkpoint.h5
# Epoch 16/300
# 29/29 [==============================] - 1s 28ms/step - loss: 223.1603 - mean_absolute_error: 9.9226 - val_loss: 2549.2896 - val_mean_absolute_error: 48.1106
#
# Epoch 00016: val_loss improved from 2645.99365 to 2549.28955, saving model to model_checkpoint.h5
# Epoch 17/300
# 29/29 [==============================] - 1s 28ms/step - loss: 214.9310 - mean_absolute_error: 9.7236 - val_loss: 2459.0105 - val_mean_absolute_error: 47.1631
#
# Epoch 00017: val_loss improved from 2549.28955 to 2459.01050, saving model to model_checkpoint.h5
# Epoch 18/300
# 29/29 [==============================] - 1s 28ms/step - loss: 199.1291 - mean_absolute_error: 9.3756 - val_loss: 2373.5652 - val_mean_absolute_error: 46.2485
#
# Epoch 00018: val_loss improved from 2459.01050 to 2373.56519, saving model to model_checkpoint.h5
# Epoch 19/300
# 29/29 [==============================] - 1s 28ms/step - loss: 186.0995 - mean_absolute_error: 8.9631 - val_loss: 2288.8665 - val_mean_absolute_error: 45.3235
#
# Epoch 00019: val_loss improved from 2373.56519 to 2288.86646, saving model to model_checkpoint.h5
# Epoch 20/300
# 29/29 [==============================] - 1s 28ms/step - loss: 174.9866 - mean_absolute_error: 8.6716 - val_loss: 2207.2607 - val_mean_absolute_error: 44.4141
#
# Epoch 00020: val_loss improved from 2288.86646 to 2207.26074, saving model to model_checkpoint.h5
# Epoch 21/300
# 29/29 [==============================] - 1s 28ms/step - loss: 165.1034 - mean_absolute_error: 8.3428 - val_loss: 2129.0791 - val_mean_absolute_error: 43.5250
#
# Epoch 00021: val_loss improved from 2207.26074 to 2129.07910, saving model to model_checkpoint.h5
# Epoch 22/300
# 29/29 [==============================] - 1s 28ms/step - loss: 155.9843 - mean_absolute_error: 8.1173 - val_loss: 2054.2339 - val_mean_absolute_error: 42.6566
#
# Epoch 00022: val_loss improved from 2129.07910 to 2054.23389, saving model to model_checkpoint.h5
# Epoch 23/300
# 29/29 [==============================] - 1s 28ms/step - loss: 147.8101 - mean_absolute_error: 7.8694 - val_loss: 1982.7146 - val_mean_absolute_error: 41.8110
#
# Epoch 00023: val_loss improved from 2054.23389 to 1982.71460, saving model to model_checkpoint.h5
# Epoch 24/300
# 29/29 [==============================] - 1s 29ms/step - loss: 141.2248 - mean_absolute_error: 7.7441 - val_loss: 1915.1722 - val_mean_absolute_error: 40.9996
#
# Epoch 00024: val_loss improved from 1982.71460 to 1915.17224, saving model to model_checkpoint.h5
# Epoch 25/300
# 29/29 [==============================] - 1s 28ms/step - loss: 134.1078 - mean_absolute_error: 7.5195 - val_loss: 1850.7139 - val_mean_absolute_error: 40.2157
#
# Epoch 00025: val_loss improved from 1915.17224 to 1850.71387, saving model to model_checkpoint.h5
# Epoch 26/300
# 29/29 [==============================] - 1s 29ms/step - loss: 127.9110 - mean_absolute_error: 7.3559 - val_loss: 1789.3330 - val_mean_absolute_error: 39.4610
#
# Epoch 00026: val_loss improved from 1850.71387 to 1789.33301, saving model to model_checkpoint.h5
# Epoch 27/300
# 29/29 [==============================] - 1s 27ms/step - loss: 121.2721 - mean_absolute_error: 7.0818 - val_loss: 1730.5327 - val_mean_absolute_error: 38.7240
#
# Epoch 00027: val_loss improved from 1789.33301 to 1730.53271, saving model to model_checkpoint.h5
# Epoch 28/300
# 29/29 [==============================] - 1s 28ms/step - loss: 115.9711 - mean_absolute_error: 6.9325 - val_loss: 1674.5033 - val_mean_absolute_error: 38.0081
#
# Epoch 00028: val_loss improved from 1730.53271 to 1674.50330, saving model to model_checkpoint.h5
# Epoch 29/300
# 29/29 [==============================] - 1s 28ms/step - loss: 110.8366 - mean_absolute_error: 6.7683 - val_loss: 1621.1211 - val_mean_absolute_error: 37.3144
#
# Epoch 00029: val_loss improved from 1674.50330 to 1621.12109, saving model to model_checkpoint.h5
# Epoch 30/300
# 29/29 [==============================] - 1s 28ms/step - loss: 107.8055 - mean_absolute_error: 6.7517 - val_loss: 1570.8640 - val_mean_absolute_error: 36.6515
#
# Epoch 00030: val_loss improved from 1621.12109 to 1570.86401, saving model to model_checkpoint.h5
# Epoch 31/300
# 29/29 [==============================] - 1s 29ms/step - loss: 102.1365 - mean_absolute_error: 6.5459 - val_loss: 1522.5549 - val_mean_absolute_error: 36.0027
#
# Epoch 00031: val_loss improved from 1570.86401 to 1522.55493, saving model to model_checkpoint.h5
# Epoch 32/300
# 29/29 [==============================] - 1s 29ms/step - loss: 99.1192 - mean_absolute_error: 6.4726 - val_loss: 1476.4009 - val_mean_absolute_error: 35.3770
#
# Epoch 00032: val_loss improved from 1522.55493 to 1476.40088, saving model to model_checkpoint.h5
# Epoch 33/300
# 29/29 [==============================] - 1s 28ms/step - loss: 95.1031 - mean_absolute_error: 6.3237 - val_loss: 1432.6042 - val_mean_absolute_error: 34.7761
#
# Epoch 00033: val_loss improved from 1476.40088 to 1432.60425, saving model to model_checkpoint.h5
# Epoch 34/300
# 29/29 [==============================] - 1s 29ms/step - loss: 95.0850 - mean_absolute_error: 6.4989 - val_loss: 1391.6670 - val_mean_absolute_error: 34.2049
#
# Epoch 00034: val_loss improved from 1432.60425 to 1391.66699, saving model to model_checkpoint.h5
# Epoch 35/300
# 29/29 [==============================] - 1s 28ms/step - loss: 94.8286 - mean_absolute_error: 6.5368 - val_loss: 1353.8965 - val_mean_absolute_error: 33.6714
#
# Epoch 00035: val_loss improved from 1391.66699 to 1353.89648, saving model to model_checkpoint.h5
# Epoch 36/300
# 29/29 [==============================] - 1s 28ms/step - loss: 87.7010 - mean_absolute_error: 6.1873 - val_loss: 1316.5156 - val_mean_absolute_error: 33.1356
#
# Epoch 00036: val_loss improved from 1353.89648 to 1316.51562, saving model to model_checkpoint.h5
# Epoch 37/300
# 29/29 [==============================] - 1s 28ms/step - loss: 90.2070 - mean_absolute_error: 6.4072 - val_loss: 1282.9082 - val_mean_absolute_error: 32.6520
#
# Epoch 00037: val_loss improved from 1316.51562 to 1282.90820, saving model to model_checkpoint.h5
# Epoch 38/300
# 29/29 [==============================] - 1s 29ms/step - loss: 82.2399 - mean_absolute_error: 6.0561 - val_loss: 1248.2261 - val_mean_absolute_error: 32.1485
#
# Epoch 00038: val_loss improved from 1282.90820 to 1248.22607, saving model to model_checkpoint.h5
# Epoch 39/300
# 29/29 [==============================] - 1s 28ms/step - loss: 79.6620 - mean_absolute_error: 5.9624 - val_loss: 1215.1090 - val_mean_absolute_error: 31.6605
#
# Epoch 00039: val_loss improved from 1248.22607 to 1215.10901, saving model to model_checkpoint.h5
# Epoch 40/300
# 29/29 [==============================] - 1s 30ms/step - loss: 78.6092 - mean_absolute_error: 5.9885 - val_loss: 1183.5076 - val_mean_absolute_error: 31.1886
#
# Epoch 00040: val_loss improved from 1215.10901 to 1183.50757, saving model to model_checkpoint.h5
# Epoch 41/300
# 29/29 [==============================] - 1s 29ms/step - loss: 80.8264 - mean_absolute_error: 6.1873 - val_loss: 1155.5411 - val_mean_absolute_error: 30.7641
#
# Epoch 00041: val_loss improved from 1183.50757 to 1155.54114, saving model to model_checkpoint.h5
# Epoch 42/300
# 29/29 [==============================] - 1s 29ms/step - loss: 74.4085 - mean_absolute_error: 5.8092 - val_loss: 1126.4287 - val_mean_absolute_error: 30.3269
#
# Epoch 00042: val_loss improved from 1155.54114 to 1126.42871, saving model to model_checkpoint.h5
# Epoch 43/300
# 29/29 [==============================] - 1s 29ms/step - loss: 72.3609 - mean_absolute_error: 5.7555 - val_loss: 1098.1498 - val_mean_absolute_error: 29.8955
#
# Epoch 00043: val_loss improved from 1126.42871 to 1098.14978, saving model to model_checkpoint.h5
# Epoch 44/300
# 29/29 [==============================] - 1s 28ms/step - loss: 73.1037 - mean_absolute_error: 5.8704 - val_loss: 1069.7623 - val_mean_absolute_error: 29.4554
#
# Epoch 00044: val_loss improved from 1098.14978 to 1069.76233, saving model to model_checkpoint.h5
# Epoch 45/300
# 29/29 [==============================] - 1s 28ms/step - loss: 68.3679 - mean_absolute_error: 5.6661 - val_loss: 1041.5852 - val_mean_absolute_error: 29.0137
#
# Epoch 00045: val_loss improved from 1069.76233 to 1041.58521, saving model to model_checkpoint.h5
# Epoch 46/300
# 29/29 [==============================] - 1s 29ms/step - loss: 69.0664 - mean_absolute_error: 5.6929 - val_loss: 1013.7567 - val_mean_absolute_error: 28.5655
#
# Epoch 00046: val_loss improved from 1041.58521 to 1013.75671, saving model to model_checkpoint.h5
# Epoch 47/300
# 29/29 [==============================] - 1s 29ms/step - loss: 71.0701 - mean_absolute_error: 5.8277 - val_loss: 990.0681 - val_mean_absolute_error: 28.1779
#
# Epoch 00047: val_loss improved from 1013.75671 to 990.06812, saving model to model_checkpoint.h5
# Epoch 48/300
# 29/29 [==============================] - 1s 27ms/step - loss: 88.4549 - mean_absolute_error: 6.9730 - val_loss: 968.5026 - val_mean_absolute_error: 27.8342
#
# Epoch 00048: val_loss improved from 990.06812 to 968.50256, saving model to model_checkpoint.h5
# Epoch 49/300
# 29/29 [==============================] - 1s 29ms/step - loss: 69.7833 - mean_absolute_error: 5.8895 - val_loss: 945.0843 - val_mean_absolute_error: 27.4384
#
# Epoch 00049: val_loss improved from 968.50256 to 945.08429, saving model to model_checkpoint.h5
# Epoch 50/300
# 29/29 [==============================] - 1s 28ms/step - loss: 62.6483 - mean_absolute_error: 5.4765 - val_loss: 921.2677 - val_mean_absolute_error: 27.0357
#
# Epoch 00050: val_loss improved from 945.08429 to 921.26770, saving model to model_checkpoint.h5
# Epoch 51/300
# 29/29 [==============================] - 1s 28ms/step - loss: 61.0038 - mean_absolute_error: 5.4018 - val_loss: 898.4705 - val_mean_absolute_error: 26.6494
#
# Epoch 00051: val_loss improved from 921.26770 to 898.47052, saving model to model_checkpoint.h5
# Epoch 52/300
# 29/29 [==============================] - 1s 28ms/step - loss: 57.8405 - mean_absolute_error: 5.2418 - val_loss: 875.4009 - val_mean_absolute_error: 26.2420
#
# Epoch 00052: val_loss improved from 898.47052 to 875.40088, saving model to model_checkpoint.h5
# Epoch 53/300
# 29/29 [==============================] - 1s 29ms/step - loss: 55.4353 - mean_absolute_error: 5.1230 - val_loss: 851.8330 - val_mean_absolute_error: 25.8281
#
# Epoch 00053: val_loss improved from 875.40088 to 851.83301, saving model to model_checkpoint.h5
# Epoch 54/300
# 29/29 [==============================] - 1s 29ms/step - loss: 54.9460 - mean_absolute_error: 5.1271 - val_loss: 829.7760 - val_mean_absolute_error: 25.4345
#
# Epoch 00054: val_loss improved from 851.83301 to 829.77600, saving model to model_checkpoint.h5
# Epoch 55/300
# 29/29 [==============================] - 1s 30ms/step - loss: 55.0055 - mean_absolute_error: 5.1586 - val_loss: 808.7951 - val_mean_absolute_error: 25.0591
#
# Epoch 00055: val_loss improved from 829.77600 to 808.79510, saving model to model_checkpoint.h5
# Epoch 56/300
# 29/29 [==============================] - 1s 29ms/step - loss: 55.1762 - mean_absolute_error: 5.2010 - val_loss: 788.6601 - val_mean_absolute_error: 24.6984
#
# Epoch 00056: val_loss improved from 808.79510 to 788.66010, saving model to model_checkpoint.h5
# Epoch 57/300
# 29/29 [==============================] - 1s 28ms/step - loss: 53.0749 - mean_absolute_error: 5.0723 - val_loss: 769.7326 - val_mean_absolute_error: 24.3300
#
# Epoch 00057: val_loss improved from 788.66010 to 769.73260, saving model to model_checkpoint.h5
# Epoch 58/300
# 29/29 [==============================] - 1s 29ms/step - loss: 49.6743 - mean_absolute_error: 4.8633 - val_loss: 750.4918 - val_mean_absolute_error: 23.9629
#
# Epoch 00058: val_loss improved from 769.73260 to 750.49176, saving model to model_checkpoint.h5
# Epoch 59/300
# 29/29 [==============================] - 1s 28ms/step - loss: 48.9343 - mean_absolute_error: 4.8197 - val_loss: 732.1058 - val_mean_absolute_error: 23.6115
#
# Epoch 00059: val_loss improved from 750.49176 to 732.10577, saving model to model_checkpoint.h5
# Epoch 60/300
# 29/29 [==============================] - 1s 28ms/step - loss: 48.2474 - mean_absolute_error: 4.8184 - val_loss: 714.2515 - val_mean_absolute_error: 23.2684
#
# Epoch 00060: val_loss improved from 732.10577 to 714.25146, saving model to model_checkpoint.h5
# Epoch 61/300
# 29/29 [==============================] - 1s 28ms/step - loss: 48.0896 - mean_absolute_error: 4.8370 - val_loss: 697.1913 - val_mean_absolute_error: 22.9318
#
# Epoch 00061: val_loss improved from 714.25146 to 697.19135, saving model to model_checkpoint.h5
# Epoch 62/300
# 29/29 [==============================] - 1s 30ms/step - loss: 50.1659 - mean_absolute_error: 5.0291 - val_loss: 680.0425 - val_mean_absolute_error: 22.5916
#
# Epoch 00062: val_loss improved from 697.19135 to 680.04248, saving model to model_checkpoint.h5
# Epoch 63/300
# 29/29 [==============================] - 1s 29ms/step - loss: 47.8285 - mean_absolute_error: 4.9085 - val_loss: 664.3647 - val_mean_absolute_error: 22.2760
#
# Epoch 00063: val_loss improved from 680.04248 to 664.36475, saving model to model_checkpoint.h5
# Epoch 64/300
# 29/29 [==============================] - 1s 28ms/step - loss: 44.8899 - mean_absolute_error: 4.6881 - val_loss: 648.4318 - val_mean_absolute_error: 21.9532
#
# Epoch 00064: val_loss improved from 664.36475 to 648.43176, saving model to model_checkpoint.h5
# Epoch 65/300
# 29/29 [==============================] - 1s 29ms/step - loss: 45.7030 - mean_absolute_error: 4.7895 - val_loss: 633.2563 - val_mean_absolute_error: 21.6541
#
# Epoch 00065: val_loss improved from 648.43176 to 633.25635, saving model to model_checkpoint.h5
# Epoch 66/300
# 29/29 [==============================] - 1s 28ms/step - loss: 48.4975 - mean_absolute_error: 4.9883 - val_loss: 619.7089 - val_mean_absolute_error: 21.3791
#
# Epoch 00066: val_loss improved from 633.25635 to 619.70886, saving model to model_checkpoint.h5
# Epoch 67/300
# 29/29 [==============================] - 1s 29ms/step - loss: 46.5907 - mean_absolute_error: 4.8634 - val_loss: 606.4387 - val_mean_absolute_error: 21.0897
#
# Epoch 00067: val_loss improved from 619.70886 to 606.43872, saving model to model_checkpoint.h5
# Epoch 68/300
# 29/29 [==============================] - 1s 29ms/step - loss: 43.9225 - mean_absolute_error: 4.6542 - val_loss: 593.4579 - val_mean_absolute_error: 20.8212
#
# Epoch 00068: val_loss improved from 606.43872 to 593.45789, saving model to model_checkpoint.h5
# Epoch 69/300
# 29/29 [==============================] - 1s 29ms/step - loss: 42.0552 - mean_absolute_error: 4.5644 - val_loss: 580.8085 - val_mean_absolute_error: 20.5531
#
# Epoch 00069: val_loss improved from 593.45789 to 580.80847, saving model to model_checkpoint.h5
# Epoch 70/300
# 29/29 [==============================] - 1s 29ms/step - loss: 40.8955 - mean_absolute_error: 4.4718 - val_loss: 568.3509 - val_mean_absolute_error: 20.2827
#
# Epoch 00070: val_loss improved from 580.80847 to 568.35089, saving model to model_checkpoint.h5
# Epoch 71/300
# 29/29 [==============================] - 1s 29ms/step - loss: 40.3483 - mean_absolute_error: 4.4767 - val_loss: 556.4232 - val_mean_absolute_error: 20.0381
#
# Epoch 00071: val_loss improved from 568.35089 to 556.42316, saving model to model_checkpoint.h5
# Epoch 72/300
# 29/29 [==============================] - 1s 29ms/step - loss: 40.1584 - mean_absolute_error: 4.4881 - val_loss: 544.6852 - val_mean_absolute_error: 19.7721
#
# Epoch 00072: val_loss improved from 556.42316 to 544.68518, saving model to model_checkpoint.h5
# Epoch 73/300
# 29/29 [==============================] - 1s 28ms/step - loss: 39.4974 - mean_absolute_error: 4.4388 - val_loss: 533.7333 - val_mean_absolute_error: 19.5436
#
# Epoch 00073: val_loss improved from 544.68518 to 533.73328, saving model to model_checkpoint.h5
# Epoch 74/300
# 29/29 [==============================] - 1s 29ms/step - loss: 38.6881 - mean_absolute_error: 4.3993 - val_loss: 522.5554 - val_mean_absolute_error: 19.2743
#
# Epoch 00074: val_loss improved from 533.73328 to 522.55536, saving model to model_checkpoint.h5
# Epoch 75/300
# 29/29 [==============================] - 1s 30ms/step - loss: 38.0387 - mean_absolute_error: 4.3527 - val_loss: 512.5053 - val_mean_absolute_error: 19.0515
#
# Epoch 00075: val_loss improved from 522.55536 to 512.50531, saving model to model_checkpoint.h5
# Epoch 76/300
# 29/29 [==============================] - 1s 30ms/step - loss: 37.4048 - mean_absolute_error: 4.3445 - val_loss: 502.3809 - val_mean_absolute_error: 18.8383
#
# Epoch 00076: val_loss improved from 512.50531 to 502.38086, saving model to model_checkpoint.h5
# Epoch 77/300
# 29/29 [==============================] - 1s 29ms/step - loss: 37.2881 - mean_absolute_error: 4.3374 - val_loss: 492.5688 - val_mean_absolute_error: 18.6011
#
# Epoch 00077: val_loss improved from 502.38086 to 492.56876, saving model to model_checkpoint.h5
# Epoch 78/300
# 29/29 [==============================] - 1s 30ms/step - loss: 37.4237 - mean_absolute_error: 4.3809 - val_loss: 482.7808 - val_mean_absolute_error: 18.3733
#
# Epoch 00078: val_loss improved from 492.56876 to 482.78076, saving model to model_checkpoint.h5
# Epoch 79/300
# 29/29 [==============================] - 1s 29ms/step - loss: 37.6283 - mean_absolute_error: 4.3939 - val_loss: 474.0088 - val_mean_absolute_error: 18.1552
#
# Epoch 00079: val_loss improved from 482.78076 to 474.00879, saving model to model_checkpoint.h5
# Epoch 80/300
# 29/29 [==============================] - 1s 29ms/step - loss: 37.3019 - mean_absolute_error: 4.3639 - val_loss: 464.7021 - val_mean_absolute_error: 17.9668
#
# Epoch 00080: val_loss improved from 474.00879 to 464.70206, saving model to model_checkpoint.h5
# Epoch 81/300
# 29/29 [==============================] - 1s 30ms/step - loss: 40.1971 - mean_absolute_error: 4.5541 - val_loss: 457.5304 - val_mean_absolute_error: 17.7763
#
# Epoch 00081: val_loss improved from 464.70206 to 457.53043, saving model to model_checkpoint.h5
# Epoch 82/300
# 29/29 [==============================] - 1s 29ms/step - loss: 47.9463 - mean_absolute_error: 5.1344 - val_loss: 448.9094 - val_mean_absolute_error: 17.5967
#
# Epoch 00082: val_loss improved from 457.53043 to 448.90936, saving model to model_checkpoint.h5
# Epoch 83/300
# 29/29 [==============================] - 1s 29ms/step - loss: 41.4236 - mean_absolute_error: 4.6914 - val_loss: 441.9785 - val_mean_absolute_error: 17.4284
#
# Epoch 00083: val_loss improved from 448.90936 to 441.97849, saving model to model_checkpoint.h5
# Epoch 84/300
# 29/29 [==============================] - 1s 30ms/step - loss: 36.8529 - mean_absolute_error: 4.3520 - val_loss: 435.1393 - val_mean_absolute_error: 17.2714
#
# Epoch 00084: val_loss improved from 441.97849 to 435.13928, saving model to model_checkpoint.h5
# Epoch 85/300
# 29/29 [==============================] - 1s 30ms/step - loss: 36.2318 - mean_absolute_error: 4.3386 - val_loss: 428.1292 - val_mean_absolute_error: 17.0966
#
# Epoch 00085: val_loss improved from 435.13928 to 428.12924, saving model to model_checkpoint.h5
# Epoch 86/300
# 29/29 [==============================] - 1s 30ms/step - loss: 37.5525 - mean_absolute_error: 4.4035 - val_loss: 421.2160 - val_mean_absolute_error: 16.8938
#
# Epoch 00086: val_loss improved from 428.12924 to 421.21597, saving model to model_checkpoint.h5
# Epoch 87/300
# 29/29 [==============================] - 1s 29ms/step - loss: 43.2188 - mean_absolute_error: 4.6744 - val_loss: 413.9283 - val_mean_absolute_error: 16.7362
#
# Epoch 00087: val_loss improved from 421.21597 to 413.92828, saving model to model_checkpoint.h5
# Epoch 88/300
# 29/29 [==============================] - 1s 29ms/step - loss: 41.0825 - mean_absolute_error: 4.5698 - val_loss: 407.2487 - val_mean_absolute_error: 16.6549
#
# Epoch 00088: val_loss improved from 413.92828 to 407.24869, saving model to model_checkpoint.h5
# Epoch 89/300
# 29/29 [==============================] - 1s 29ms/step - loss: 37.1322 - mean_absolute_error: 4.3867 - val_loss: 402.4180 - val_mean_absolute_error: 16.5120
#
# Epoch 00089: val_loss improved from 407.24869 to 402.41803, saving model to model_checkpoint.h5
# Epoch 90/300
# 29/29 [==============================] - 1s 31ms/step - loss: 34.8530 - mean_absolute_error: 4.2613 - val_loss: 397.6665 - val_mean_absolute_error: 16.3909
#
# Epoch 00090: val_loss improved from 402.41803 to 397.66647, saving model to model_checkpoint.h5
# Epoch 91/300
# 29/29 [==============================] - 1s 29ms/step - loss: 33.6698 - mean_absolute_error: 4.1889 - val_loss: 391.8053 - val_mean_absolute_error: 16.2124
#
# Epoch 00091: val_loss improved from 397.66647 to 391.80530, saving model to model_checkpoint.h5
# Epoch 92/300
# 29/29 [==============================] - 1s 28ms/step - loss: 33.0205 - mean_absolute_error: 4.1391 - val_loss: 386.5411 - val_mean_absolute_error: 16.1319
#
# Epoch 00092: val_loss improved from 391.80530 to 386.54108, saving model to model_checkpoint.h5
# Epoch 93/300
# 29/29 [==============================] - 1s 29ms/step - loss: 33.1268 - mean_absolute_error: 4.2096 - val_loss: 380.7513 - val_mean_absolute_error: 15.9537
#
# Epoch 00093: val_loss improved from 386.54108 to 380.75134, saving model to model_checkpoint.h5
# Epoch 94/300
# 29/29 [==============================] - 1s 30ms/step - loss: 33.5153 - mean_absolute_error: 4.1657 - val_loss: 374.6623 - val_mean_absolute_error: 15.7933
#
# Epoch 00094: val_loss improved from 380.75134 to 374.66229, saving model to model_checkpoint.h5
# Epoch 95/300
# 29/29 [==============================] - 1s 29ms/step - loss: 32.8021 - mean_absolute_error: 4.1392 - val_loss: 369.0755 - val_mean_absolute_error: 15.6510
#
# Epoch 00095: val_loss improved from 374.66229 to 369.07547, saving model to model_checkpoint.h5
# Epoch 96/300
# 29/29 [==============================] - 1s 29ms/step - loss: 32.1287 - mean_absolute_error: 4.0844 - val_loss: 363.1436 - val_mean_absolute_error: 15.5057
#
# Epoch 00096: val_loss improved from 369.07547 to 363.14362, saving model to model_checkpoint.h5
# Epoch 97/300
# 29/29 [==============================] - 1s 29ms/step - loss: 31.6615 - mean_absolute_error: 4.0663 - val_loss: 357.2479 - val_mean_absolute_error: 15.3598
#
# Epoch 00097: val_loss improved from 363.14362 to 357.24792, saving model to model_checkpoint.h5
# Epoch 98/300
# 29/29 [==============================] - 1s 31ms/step - loss: 31.6013 - mean_absolute_error: 4.0891 - val_loss: 351.7311 - val_mean_absolute_error: 15.2203
#
# Epoch 00098: val_loss improved from 357.24792 to 351.73111, saving model to model_checkpoint.h5
# Epoch 99/300
# 29/29 [==============================] - 1s 29ms/step - loss: 31.2063 - mean_absolute_error: 4.0529 - val_loss: 346.5641 - val_mean_absolute_error: 15.0924
#
# Epoch 00099: val_loss improved from 351.73111 to 346.56409, saving model to model_checkpoint.h5
# Epoch 100/300
# 29/29 [==============================] - 1s 29ms/step - loss: 31.1102 - mean_absolute_error: 4.0316 - val_loss: 341.5911 - val_mean_absolute_error: 14.9650
#
# Epoch 00100: val_loss improved from 346.56409 to 341.59109, saving model to model_checkpoint.h5
# Epoch 101/300
# 29/29 [==============================] - 1s 30ms/step - loss: 31.0063 - mean_absolute_error: 4.0737 - val_loss: 336.6952 - val_mean_absolute_error: 14.8431
#
# Epoch 00101: val_loss improved from 341.59109 to 336.69516, saving model to model_checkpoint.h5
# Epoch 102/300
# 29/29 [==============================] - 1s 31ms/step - loss: 31.5123 - mean_absolute_error: 4.1384 - val_loss: 332.1759 - val_mean_absolute_error: 14.7340
#
# Epoch 00102: val_loss improved from 336.69516 to 332.17587, saving model to model_checkpoint.h5
# Epoch 103/300
# 29/29 [==============================] - 1s 30ms/step - loss: 31.4303 - mean_absolute_error: 4.1389 - val_loss: 327.6721 - val_mean_absolute_error: 14.6138
#
# Epoch 00103: val_loss improved from 332.17587 to 327.67215, saving model to model_checkpoint.h5
# Epoch 104/300
# 29/29 [==============================] - 1s 29ms/step - loss: 31.4500 - mean_absolute_error: 4.0978 - val_loss: 323.1283 - val_mean_absolute_error: 14.4932
#
# Epoch 00104: val_loss improved from 327.67215 to 323.12833, saving model to model_checkpoint.h5
# Epoch 105/300
# 29/29 [==============================] - 1s 29ms/step - loss: 30.9306 - mean_absolute_error: 3.9989 - val_loss: 318.9314 - val_mean_absolute_error: 14.3874
#
# Epoch 00105: val_loss improved from 323.12833 to 318.93140, saving model to model_checkpoint.h5
# Epoch 106/300
# 29/29 [==============================] - 1s 29ms/step - loss: 29.9867 - mean_absolute_error: 3.9669 - val_loss: 314.8881 - val_mean_absolute_error: 14.2750
#
# Epoch 00106: val_loss improved from 318.93140 to 314.88806, saving model to model_checkpoint.h5
# Epoch 107/300
# 29/29 [==============================] - 1s 31ms/step - loss: 32.4879 - mean_absolute_error: 4.1750 - val_loss: 310.4397 - val_mean_absolute_error: 14.1680
#
# Epoch 00107: val_loss improved from 314.88806 to 310.43967, saving model to model_checkpoint.h5
# Epoch 108/300
# 29/29 [==============================] - 1s 29ms/step - loss: 32.9299 - mean_absolute_error: 4.2256 - val_loss: 306.6583 - val_mean_absolute_error: 14.0740
#
# Epoch 00108: val_loss improved from 310.43967 to 306.65833, saving model to model_checkpoint.h5
# Epoch 109/300
# 29/29 [==============================] - 1s 30ms/step - loss: 37.8891 - mean_absolute_error: 4.5710 - val_loss: 303.4128 - val_mean_absolute_error: 13.9707
#
# Epoch 00109: val_loss improved from 306.65833 to 303.41278, saving model to model_checkpoint.h5
# Epoch 110/300
# 29/29 [==============================] - 1s 29ms/step - loss: 32.7880 - mean_absolute_error: 4.1939 - val_loss: 298.9561 - val_mean_absolute_error: 13.8719
#
# Epoch 00110: val_loss improved from 303.41278 to 298.95615, saving model to model_checkpoint.h5
# Epoch 111/300
# 29/29 [==============================] - 1s 28ms/step - loss: 32.0391 - mean_absolute_error: 4.1912 - val_loss: 294.6065 - val_mean_absolute_error: 13.7432
#
# Epoch 00111: val_loss improved from 298.95615 to 294.60651, saving model to model_checkpoint.h5
# Epoch 112/300
# 29/29 [==============================] - 1s 29ms/step - loss: 31.2876 - mean_absolute_error: 4.0948 - val_loss: 291.0887 - val_mean_absolute_error: 13.6349
#
# Epoch 00112: val_loss improved from 294.60651 to 291.08868, saving model to model_checkpoint.h5
# Epoch 113/300
# 29/29 [==============================] - 1s 30ms/step - loss: 30.5956 - mean_absolute_error: 4.0861 - val_loss: 286.3518 - val_mean_absolute_error: 13.5378
#
# Epoch 00113: val_loss improved from 291.08868 to 286.35181, saving model to model_checkpoint.h5
# Epoch 114/300
# 29/29 [==============================] - 1s 29ms/step - loss: 31.3092 - mean_absolute_error: 4.0966 - val_loss: 282.8982 - val_mean_absolute_error: 13.4193
#
# Epoch 00114: val_loss improved from 286.35181 to 282.89816, saving model to model_checkpoint.h5
# Epoch 115/300
# 29/29 [==============================] - 1s 28ms/step - loss: 30.1823 - mean_absolute_error: 4.0712 - val_loss: 279.9926 - val_mean_absolute_error: 13.3229
#
# Epoch 00115: val_loss improved from 282.89816 to 279.99261, saving model to model_checkpoint.h5
# Epoch 116/300
# 29/29 [==============================] - 1s 29ms/step - loss: 33.3120 - mean_absolute_error: 4.2200 - val_loss: 275.4355 - val_mean_absolute_error: 13.2018
#
# Epoch 00116: val_loss improved from 279.99261 to 275.43555, saving model to model_checkpoint.h5
# Epoch 117/300
# 29/29 [==============================] - 1s 30ms/step - loss: 35.3055 - mean_absolute_error: 4.4576 - val_loss: 272.1416 - val_mean_absolute_error: 13.1044
#
# Epoch 00117: val_loss improved from 275.43555 to 272.14157, saving model to model_checkpoint.h5
# Epoch 118/300
# 29/29 [==============================] - 1s 30ms/step - loss: 44.7756 - mean_absolute_error: 5.0880 - val_loss: 266.7797 - val_mean_absolute_error: 12.9482
#
# Epoch 00118: val_loss improved from 272.14157 to 266.77966, saving model to model_checkpoint.h5
# Epoch 119/300
# 29/29 [==============================] - 1s 32ms/step - loss: 37.4654 - mean_absolute_error: 4.5149 - val_loss: 263.9784 - val_mean_absolute_error: 12.8616
#
# Epoch 00119: val_loss improved from 266.77966 to 263.97842, saving model to model_checkpoint.h5
# Epoch 120/300
# 29/29 [==============================] - 1s 29ms/step - loss: 34.7792 - mean_absolute_error: 4.3983 - val_loss: 259.9631 - val_mean_absolute_error: 12.7717
#
# Epoch 00120: val_loss improved from 263.97842 to 259.96310, saving model to model_checkpoint.h5
# Epoch 121/300
# 29/29 [==============================] - 1s 29ms/step - loss: 32.0508 - mean_absolute_error: 4.1825 - val_loss: 256.4461 - val_mean_absolute_error: 12.6748
#
# Epoch 00121: val_loss improved from 259.96310 to 256.44614, saving model to model_checkpoint.h5
# Epoch 122/300
# 29/29 [==============================] - 1s 29ms/step - loss: 33.1835 - mean_absolute_error: 4.2354 - val_loss: 255.9285 - val_mean_absolute_error: 12.7756
#
# Epoch 00122: val_loss improved from 256.44614 to 255.92854, saving model to model_checkpoint.h5
# Epoch 123/300
# 29/29 [==============================] - 1s 30ms/step - loss: 28.9919 - mean_absolute_error: 3.9550 - val_loss: 252.4536 - val_mean_absolute_error: 12.5715
#
# Epoch 00123: val_loss improved from 255.92854 to 252.45357, saving model to model_checkpoint.h5
# Epoch 124/300
# 29/29 [==============================] - 1s 29ms/step - loss: 28.9117 - mean_absolute_error: 3.9777 - val_loss: 248.1628 - val_mean_absolute_error: 12.4065
#
# Epoch 00124: val_loss improved from 252.45357 to 248.16281, saving model to model_checkpoint.h5
# Epoch 125/300
# 29/29 [==============================] - 1s 30ms/step - loss: 29.4438 - mean_absolute_error: 3.9849 - val_loss: 244.0798 - val_mean_absolute_error: 12.2925
#
# Epoch 00125: val_loss improved from 248.16281 to 244.07976, saving model to model_checkpoint.h5
# Epoch 126/300
# 29/29 [==============================] - 1s 29ms/step - loss: 30.8156 - mean_absolute_error: 4.0140 - val_loss: 242.3275 - val_mean_absolute_error: 12.2222
#
# Epoch 00126: val_loss improved from 244.07976 to 242.32755, saving model to model_checkpoint.h5
# Epoch 127/300
# 29/29 [==============================] - 1s 29ms/step - loss: 28.4667 - mean_absolute_error: 3.8967 - val_loss: 238.1582 - val_mean_absolute_error: 12.0891
#
# Epoch 00127: val_loss improved from 242.32755 to 238.15816, saving model to model_checkpoint.h5
# Epoch 128/300
# 29/29 [==============================] - 1s 30ms/step - loss: 27.7695 - mean_absolute_error: 3.8584 - val_loss: 234.3978 - val_mean_absolute_error: 11.9572
#
# Epoch 00128: val_loss improved from 238.15816 to 234.39777, saving model to model_checkpoint.h5
# Epoch 129/300
# 29/29 [==============================] - 1s 31ms/step - loss: 28.7119 - mean_absolute_error: 3.9606 - val_loss: 232.0180 - val_mean_absolute_error: 11.8920
#
# Epoch 00129: val_loss improved from 234.39777 to 232.01796, saving model to model_checkpoint.h5
# Epoch 130/300
# 29/29 [==============================] - 1s 30ms/step - loss: 28.6997 - mean_absolute_error: 3.9489 - val_loss: 227.7514 - val_mean_absolute_error: 11.7493
#
# Epoch 00130: val_loss improved from 232.01796 to 227.75140, saving model to model_checkpoint.h5
# Epoch 131/300
# 29/29 [==============================] - 1s 28ms/step - loss: 29.0416 - mean_absolute_error: 3.9069 - val_loss: 225.0160 - val_mean_absolute_error: 11.6531
#
# Epoch 00131: val_loss improved from 227.75140 to 225.01598, saving model to model_checkpoint.h5
# Epoch 132/300
# 29/29 [==============================] - 1s 29ms/step - loss: 30.1047 - mean_absolute_error: 4.0377 - val_loss: 222.6989 - val_mean_absolute_error: 11.5837
#
# Epoch 00132: val_loss improved from 225.01598 to 222.69887, saving model to model_checkpoint.h5
# Epoch 133/300
# 29/29 [==============================] - 1s 29ms/step - loss: 28.2821 - mean_absolute_error: 3.9022 - val_loss: 219.4320 - val_mean_absolute_error: 11.4748
#
# Epoch 00133: val_loss improved from 222.69887 to 219.43199, saving model to model_checkpoint.h5
# Epoch 134/300
# 29/29 [==============================] - 1s 29ms/step - loss: 29.2570 - mean_absolute_error: 4.0398 - val_loss: 217.4024 - val_mean_absolute_error: 11.4035
#
# Epoch 00134: val_loss improved from 219.43199 to 217.40240, saving model to model_checkpoint.h5
# Epoch 135/300
# 29/29 [==============================] - 1s 31ms/step - loss: 28.0902 - mean_absolute_error: 3.9586 - val_loss: 213.7416 - val_mean_absolute_error: 11.2783
#
# Epoch 00135: val_loss improved from 217.40240 to 213.74161, saving model to model_checkpoint.h5
# Epoch 136/300
# 29/29 [==============================] - 1s 29ms/step - loss: 28.4488 - mean_absolute_error: 3.9209 - val_loss: 212.5740 - val_mean_absolute_error: 11.2544
#
# Epoch 00136: val_loss improved from 213.74161 to 212.57397, saving model to model_checkpoint.h5
# Epoch 137/300
# 29/29 [==============================] - 1s 31ms/step - loss: 26.5850 - mean_absolute_error: 3.8056 - val_loss: 207.9847 - val_mean_absolute_error: 11.0653
#
# Epoch 00137: val_loss improved from 212.57397 to 207.98468, saving model to model_checkpoint.h5
# Epoch 138/300
# 29/29 [==============================] - 1s 29ms/step - loss: 26.6803 - mean_absolute_error: 3.7950 - val_loss: 206.5955 - val_mean_absolute_error: 11.0433
#
# Epoch 00138: val_loss improved from 207.98468 to 206.59549, saving model to model_checkpoint.h5
# Epoch 139/300
# 29/29 [==============================] - 1s 31ms/step - loss: 26.1143 - mean_absolute_error: 3.7918 - val_loss: 202.6788 - val_mean_absolute_error: 10.8794
#
# Epoch 00139: val_loss improved from 206.59549 to 202.67885, saving model to model_checkpoint.h5
# Epoch 140/300
# 29/29 [==============================] - 1s 30ms/step - loss: 26.8460 - mean_absolute_error: 3.7961 - val_loss: 202.5187 - val_mean_absolute_error: 10.8951
#
# Epoch 00140: val_loss improved from 202.67885 to 202.51868, saving model to model_checkpoint.h5
# Epoch 141/300
# 29/29 [==============================] - 1s 30ms/step - loss: 27.6351 - mean_absolute_error: 3.8578 - val_loss: 199.9716 - val_mean_absolute_error: 10.8035
#
# Epoch 00141: val_loss improved from 202.51868 to 199.97163, saving model to model_checkpoint.h5
# Epoch 142/300
# 29/29 [==============================] - 1s 28ms/step - loss: 29.6028 - mean_absolute_error: 3.9475 - val_loss: 199.9866 - val_mean_absolute_error: 10.8430
#
# Epoch 00142: val_loss did not improve from 199.97163
# Epoch 143/300
# 29/29 [==============================] - 1s 30ms/step - loss: 26.5445 - mean_absolute_error: 3.7962 - val_loss: 194.3458 - val_mean_absolute_error: 10.6582
#
# Epoch 00143: val_loss improved from 199.97163 to 194.34579, saving model to model_checkpoint.h5
# Epoch 144/300
# 29/29 [==============================] - 1s 31ms/step - loss: 27.6575 - mean_absolute_error: 3.8104 - val_loss: 191.5011 - val_mean_absolute_error: 10.4972
#
# Epoch 00144: val_loss improved from 194.34579 to 191.50113, saving model to model_checkpoint.h5
# Epoch 145/300
# 29/29 [==============================] - 1s 30ms/step - loss: 28.0496 - mean_absolute_error: 3.8618 - val_loss: 191.5034 - val_mean_absolute_error: 10.5158
#
# Epoch 00145: val_loss did not improve from 191.50113
# Epoch 146/300
# 29/29 [==============================] - 1s 30ms/step - loss: 25.4546 - mean_absolute_error: 3.7097 - val_loss: 189.2571 - val_mean_absolute_error: 10.4449
#
# Epoch 00146: val_loss improved from 191.50113 to 189.25708, saving model to model_checkpoint.h5
# Epoch 147/300
# 29/29 [==============================] - 1s 31ms/step - loss: 25.8432 - mean_absolute_error: 3.7782 - val_loss: 185.6352 - val_mean_absolute_error: 10.2826
#
# Epoch 00147: val_loss improved from 189.25708 to 185.63524, saving model to model_checkpoint.h5
# Epoch 148/300
# 29/29 [==============================] - 1s 30ms/step - loss: 29.1611 - mean_absolute_error: 3.9630 - val_loss: 182.7320 - val_mean_absolute_error: 10.1800
#
# Epoch 00148: val_loss improved from 185.63524 to 182.73201, saving model to model_checkpoint.h5
# Epoch 149/300
# 29/29 [==============================] - 1s 30ms/step - loss: 28.7546 - mean_absolute_error: 3.9442 - val_loss: 180.9454 - val_mean_absolute_error: 10.1158
#
# Epoch 00149: val_loss improved from 182.73201 to 180.94545, saving model to model_checkpoint.h5
# Epoch 150/300
# 29/29 [==============================] - 1s 29ms/step - loss: 27.1540 - mean_absolute_error: 3.8866 - val_loss: 179.2293 - val_mean_absolute_error: 10.0666
#
# Epoch 00150: val_loss improved from 180.94545 to 179.22931, saving model to model_checkpoint.h5
# Epoch 151/300
# 29/29 [==============================] - 1s 30ms/step - loss: 27.7981 - mean_absolute_error: 3.8947 - val_loss: 177.7628 - val_mean_absolute_error: 9.9783
#
# Epoch 00151: val_loss improved from 179.22931 to 177.76285, saving model to model_checkpoint.h5
# Epoch 152/300
# 29/29 [==============================] - 1s 29ms/step - loss: 27.3850 - mean_absolute_error: 3.8994 - val_loss: 174.6928 - val_mean_absolute_error: 9.8885
#
# Epoch 00152: val_loss improved from 177.76285 to 174.69279, saving model to model_checkpoint.h5
# Epoch 153/300
# 29/29 [==============================] - 1s 29ms/step - loss: 25.2527 - mean_absolute_error: 3.7155 - val_loss: 171.8555 - val_mean_absolute_error: 9.7675
#
# Epoch 00153: val_loss improved from 174.69279 to 171.85547, saving model to model_checkpoint.h5
# Epoch 154/300
# 29/29 [==============================] - 1s 29ms/step - loss: 26.3984 - mean_absolute_error: 3.7586 - val_loss: 170.9558 - val_mean_absolute_error: 9.7262
#
# Epoch 00154: val_loss improved from 171.85547 to 170.95584, saving model to model_checkpoint.h5
# Epoch 155/300
# 29/29 [==============================] - 1s 29ms/step - loss: 25.5556 - mean_absolute_error: 3.6736 - val_loss: 170.1813 - val_mean_absolute_error: 9.7317
#
# Epoch 00155: val_loss improved from 170.95584 to 170.18130, saving model to model_checkpoint.h5
# Epoch 156/300
# 29/29 [==============================] - 1s 30ms/step - loss: 24.4840 - mean_absolute_error: 3.5998 - val_loss: 166.5432 - val_mean_absolute_error: 9.5587
#
# Epoch 00156: val_loss improved from 170.18130 to 166.54320, saving model to model_checkpoint.h5
# Epoch 157/300
# 29/29 [==============================] - 1s 30ms/step - loss: 24.0894 - mean_absolute_error: 3.5848 - val_loss: 163.8683 - val_mean_absolute_error: 9.4537
#
# Epoch 00157: val_loss improved from 166.54320 to 163.86829, saving model to model_checkpoint.h5
# Epoch 158/300
# 29/29 [==============================] - 1s 29ms/step - loss: 25.4446 - mean_absolute_error: 3.6707 - val_loss: 162.3763 - val_mean_absolute_error: 9.3826
#
# Epoch 00158: val_loss improved from 163.86829 to 162.37634, saving model to model_checkpoint.h5
# Epoch 159/300
# 29/29 [==============================] - 1s 29ms/step - loss: 25.2228 - mean_absolute_error: 3.6360 - val_loss: 160.8643 - val_mean_absolute_error: 9.3355
#
# Epoch 00159: val_loss improved from 162.37634 to 160.86426, saving model to model_checkpoint.h5
# Epoch 160/300
# 29/29 [==============================] - 1s 30ms/step - loss: 25.1609 - mean_absolute_error: 3.6216 - val_loss: 160.0768 - val_mean_absolute_error: 9.3012
#
# Epoch 00160: val_loss improved from 160.86426 to 160.07684, saving model to model_checkpoint.h5
# Epoch 161/300
# 29/29 [==============================] - 1s 30ms/step - loss: 24.5340 - mean_absolute_error: 3.6111 - val_loss: 156.5735 - val_mean_absolute_error: 9.1791
#
# Epoch 00161: val_loss improved from 160.07684 to 156.57355, saving model to model_checkpoint.h5
# Epoch 162/300
# 29/29 [==============================] - 1s 30ms/step - loss: 24.5455 - mean_absolute_error: 3.5993 - val_loss: 154.0791 - val_mean_absolute_error: 9.0932
#
# Epoch 00162: val_loss improved from 156.57355 to 154.07912, saving model to model_checkpoint.h5
# Epoch 163/300
# 29/29 [==============================] - 1s 30ms/step - loss: 24.1863 - mean_absolute_error: 3.5761 - val_loss: 152.2467 - val_mean_absolute_error: 9.0085
#
# Epoch 00163: val_loss improved from 154.07912 to 152.24672, saving model to model_checkpoint.h5
# Epoch 164/300
# 29/29 [==============================] - 1s 30ms/step - loss: 26.5552 - mean_absolute_error: 3.6812 - val_loss: 154.0019 - val_mean_absolute_error: 9.1049
#
# Epoch 00164: val_loss did not improve from 152.24672
# Epoch 165/300
# 29/29 [==============================] - 1s 30ms/step - loss: 24.1236 - mean_absolute_error: 3.5629 - val_loss: 151.1730 - val_mean_absolute_error: 8.9693
#
# Epoch 00165: val_loss improved from 152.24672 to 151.17296, saving model to model_checkpoint.h5
# Epoch 166/300
# 29/29 [==============================] - 1s 31ms/step - loss: 24.4071 - mean_absolute_error: 3.5872 - val_loss: 148.1192 - val_mean_absolute_error: 8.8584
#
# Epoch 00166: val_loss improved from 151.17296 to 148.11916, saving model to model_checkpoint.h5
# Epoch 167/300
# 29/29 [==============================] - 1s 30ms/step - loss: 25.5793 - mean_absolute_error: 3.6414 - val_loss: 148.6583 - val_mean_absolute_error: 8.8897
#
# Epoch 00167: val_loss did not improve from 148.11916
# Epoch 168/300
# 29/29 [==============================] - 1s 31ms/step - loss: 25.9613 - mean_absolute_error: 3.6959 - val_loss: 145.3098 - val_mean_absolute_error: 8.7559
#
# Epoch 00168: val_loss improved from 148.11916 to 145.30983, saving model to model_checkpoint.h5
# Epoch 169/300
# 29/29 [==============================] - 1s 30ms/step - loss: 24.3066 - mean_absolute_error: 3.5522 - val_loss: 142.4182 - val_mean_absolute_error: 8.6297
#
# Epoch 00169: val_loss improved from 145.30983 to 142.41824, saving model to model_checkpoint.h5
# Epoch 170/300
# 29/29 [==============================] - 1s 31ms/step - loss: 25.7387 - mean_absolute_error: 3.7118 - val_loss: 142.5210 - val_mean_absolute_error: 8.6254
#
# Epoch 00170: val_loss did not improve from 142.41824
# Epoch 171/300
# 29/29 [==============================] - 1s 31ms/step - loss: 24.8957 - mean_absolute_error: 3.6265 - val_loss: 139.8173 - val_mean_absolute_error: 8.5201
#
# Epoch 00171: val_loss improved from 142.41824 to 139.81729, saving model to model_checkpoint.h5
# Epoch 172/300
# 29/29 [==============================] - 1s 30ms/step - loss: 26.6783 - mean_absolute_error: 3.7321 - val_loss: 138.0280 - val_mean_absolute_error: 8.4275
#
# Epoch 00172: val_loss improved from 139.81729 to 138.02797, saving model to model_checkpoint.h5
# Epoch 173/300
# 29/29 [==============================] - 1s 31ms/step - loss: 28.6408 - mean_absolute_error: 3.8935 - val_loss: 139.0580 - val_mean_absolute_error: 8.4942
#
# Epoch 00173: val_loss did not improve from 138.02797
# Epoch 174/300
# 29/29 [==============================] - 1s 31ms/step - loss: 25.4833 - mean_absolute_error: 3.7163 - val_loss: 137.9921 - val_mean_absolute_error: 8.4716
#
# Epoch 00174: val_loss improved from 138.02797 to 137.99205, saving model to model_checkpoint.h5
# Epoch 175/300
# 29/29 [==============================] - 1s 31ms/step - loss: 26.0442 - mean_absolute_error: 3.8373 - val_loss: 134.9432 - val_mean_absolute_error: 8.3181
#
# Epoch 00175: val_loss improved from 137.99205 to 134.94324, saving model to model_checkpoint.h5
# Epoch 176/300
# 29/29 [==============================] - 1s 30ms/step - loss: 24.8470 - mean_absolute_error: 3.6911 - val_loss: 133.2145 - val_mean_absolute_error: 8.2249
#
# Epoch 00176: val_loss improved from 134.94324 to 133.21449, saving model to model_checkpoint.h5
# Epoch 177/300
# 29/29 [==============================] - 1s 31ms/step - loss: 25.0004 - mean_absolute_error: 3.6859 - val_loss: 132.1191 - val_mean_absolute_error: 8.1836
#
# Epoch 00177: val_loss improved from 133.21449 to 132.11908, saving model to model_checkpoint.h5
# Epoch 178/300
# 29/29 [==============================] - 1s 31ms/step - loss: 24.8621 - mean_absolute_error: 3.6231 - val_loss: 131.7657 - val_mean_absolute_error: 8.1600
#
# Epoch 00178: val_loss improved from 132.11908 to 131.76566, saving model to model_checkpoint.h5
# Epoch 179/300
# 29/29 [==============================] - 1s 31ms/step - loss: 23.3700 - mean_absolute_error: 3.5303 - val_loss: 130.3257 - val_mean_absolute_error: 8.1195
#
# Epoch 00179: val_loss improved from 131.76566 to 130.32574, saving model to model_checkpoint.h5
# Epoch 180/300
# 29/29 [==============================] - 1s 29ms/step - loss: 23.2335 - mean_absolute_error: 3.5000 - val_loss: 128.7390 - val_mean_absolute_error: 8.0740
#
# Epoch 00180: val_loss improved from 130.32574 to 128.73895, saving model to model_checkpoint.h5
# Epoch 181/300
# 29/29 [==============================] - 1s 31ms/step - loss: 23.1411 - mean_absolute_error: 3.4767 - val_loss: 127.1900 - val_mean_absolute_error: 8.0039
#
# Epoch 00181: val_loss improved from 128.73895 to 127.19000, saving model to model_checkpoint.h5
# Epoch 182/300
# 29/29 [==============================] - 1s 31ms/step - loss: 26.1363 - mean_absolute_error: 3.6238 - val_loss: 209.4431 - val_mean_absolute_error: 11.2343
#
# Epoch 00182: val_loss did not improve from 127.19000
# Epoch 183/300
# 29/29 [==============================] - 1s 30ms/step - loss: 25.3556 - mean_absolute_error: 3.6251 - val_loss: 205.9848 - val_mean_absolute_error: 11.1215
#
# Epoch 00183: val_loss did not improve from 127.19000
# Epoch 184/300
# 29/29 [==============================] - 1s 32ms/step - loss: 30.2942 - mean_absolute_error: 3.9633 - val_loss: 205.8214 - val_mean_absolute_error: 11.2713
#
# Epoch 00184: val_loss did not improve from 127.19000
# Epoch 185/300
# 29/29 [==============================] - 1s 30ms/step - loss: 30.5745 - mean_absolute_error: 4.0102 - val_loss: 203.4198 - val_mean_absolute_error: 10.9454
#
# Epoch 00185: val_loss did not improve from 127.19000
# Epoch 186/300
# 29/29 [==============================] - 1s 32ms/step - loss: 24.8937 - mean_absolute_error: 3.5556 - val_loss: 196.4178 - val_mean_absolute_error: 10.7376
#
# Epoch 00186: val_loss did not improve from 127.19000

# %%
def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()


visualize_loss(history, "Training and Validation Loss")

# %%
def show_plot(plot_data, delta, title):
    labels = ["History", "True Future", "Model Prediction"]
    marker = [".-", "rx", "go"]
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], (future + 3) * 2])
    plt.xlabel("Time-Step")
    plt.show()
    return


for x, y in dataset_test.take(5):
    show_plot(
        [x[0][:, 0].numpy(), y[0].numpy(), model.predict(x)[0]],
        1,
        "Single Step Prediction",
    )

# %%
dataset_test_1 = keras.preprocessing.timeseries_dataset_from_array(
    x_test,
    y_test,
    sequence_length=sequence_length,
    batch_size=440,
)

# %%
for batch in dataset_test_1.take(1):
    x, y = batch

print("Input shape:", x.numpy().shape)
print("Target shape:", y.numpy().shape)
# Out:
# Input shape: (382, 40, 1)
# Target shape: (382, 1)

# %%
score = model.evaluate(x, y, verbose = 0) 

print('Test loss:', score[0]) 
print('Test accuracy:', score[1])
# Out:
# Test loss: 196.41783142089844
# Test accuracy: 10.737601280212402

# %%
prediction_df = features = pd.DataFrame(model.predict(x), columns = ["pred_value"])
prediction_df.index.name = "time"

# %%
prediction_df
# Out:
#       pred_value
# time
# 0      64.088058
# 1      67.375504
# 2      64.604782
# 3      66.384819
# 4      64.821198
# ...          ...
# 377    73.742393
# 378    73.749016
# 379    73.762985
# 380    73.751625
# 381    73.753166
#
# [382 rows x 1 columns]

# %%
true_df = features = pd.DataFrame(y.numpy(), columns = ["value"])
true_df.index.name = "time"

# %%
true_df
# Out:
#           value
# time
# 0     73.549332
# 1     62.859653
# 2     70.572067
# 3     65.010925
# 4     64.365334
# ...         ...
# 377   85.028709
# 378   91.354874
# 379   86.278694
# 380   86.458160
# 381   89.156563
#
# [382 rows x 1 columns]

# %%
def show_result_visualization(prediction, true, title):
    prediction_value = prediction["pred_value"]
    true_value = true["value"]
    time = range(len(true_df.index))
    plt.figure()
    plt.plot(time, prediction_value, "r", label="predicted_value")
    plt.plot(time, true_value, "y", label="true_value")
    plt.title(title)
    plt.xlabel("Time")
    plt.ylabel("Values")
    plt.legend()
    plt.show()


show_result_visualization(prediction_df, true_df, "Comparison")
